# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST('<insert api ID>', '<insert secret>', base_url='https://paper-api.alpaca.markets') 
account = api.get_account()
account

# https://github.com/alpacahq/alpaca-trade-api-python/tree/cd22b3393aff8df214d867b6a4723a21ea34a3c0
# Out:
# Account({   'account_blocked': False,
#     'account_number': 'PA2E0F7YERPO',
#     'buying_power': '408238.72',
#     'cash': '102059.68',
#     'created_at': '2020-11-17T17:28:00.960389Z',
#     'currency': 'USD',
#     'daytrade_count': 65,
#     'daytrading_buying_power': '408238.72',
#     'equity': '102059.68',
#     'id': '7f81289d-15ed-40ed-85a3-1e831cce3b12',
#     'initial_margin': '0',
#     'last_equity': '102059.68',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '4',
#     'pattern_day_trader': False,
#     'portfolio_value': '102059.68',
#     'regt_buying_power': '204119.36',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '0',
#     'status': 'ACTIVE',
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False})

# %%
barset = api.get_barset('TSLA',
           'day',
           limit = 10).df['TSLA']
barset
# Out:
#                              open      high       low     close     volume
# time
# 2020-12-18 00:00:00-05:00  668.90  684.7500  628.5400  664.9900  104496947
# 2020-12-21 00:00:00-05:00  666.24  668.5000  646.0700  649.7800   52689689
# 2020-12-22 00:00:00-05:00  648.00  649.8800  614.2300  640.0900   49801682
# 2020-12-23 00:00:00-05:00  632.20  651.4999  622.5701  645.9800   31228561
# 2020-12-24 00:00:00-05:00  642.99  666.0900  641.0000  661.6600   22073561
# 2020-12-28 00:00:00-05:00  674.51  681.4000  660.8000  663.7700   29644945
# 2020-12-29 00:00:00-05:00  661.00  669.9000  655.0000  665.9800   21166506
# 2020-12-30 00:00:00-05:00  672.00  696.6000  668.3603  694.7100   41421498
# 2020-12-31 00:00:00-05:00  699.99  718.7200  691.1200  705.2100   48019909
# 2021-01-04 00:00:00-05:00  719.46  744.4899  717.1895  729.1738   40865410

# %%
percent_change = (today_close - five_days_ago_close)/five_days_ago_close*100

# %%
today_close = barset['close'][-1]
five_days_ago_close = barset['close'][-6]

percent_change = (today_close - five_days_ago_close)/five_days_ago_close*100

order_info = None

if percent_change > 5:
    order_info = api.submit_order(
    symbol='TSLA',
    side='buy',
    type='market',
    qty='1',
    time_in_force='day',
    )
        
order_info
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': '4d57afe4-ac82-4bbb-87ee-631220455c6d',
#     'created_at': '2021-01-04T19:59:59.892328Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'a53034c9-4210-46ec-b64e-09b8a942fcfa',
#     'legs': None,
#     'limit_price': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-01-04T19:59:59.886588Z',
#     'symbol': 'TSLA',
#     'time_in_force': 'day',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-01-04T19:59:59.892328Z'})
